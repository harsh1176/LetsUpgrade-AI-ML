# %%
import pandas as pd 
from scipy.stats import pointbiserialr
import matplotlib.pyplot as plt

# %%
dataset = pd.read_csv("general_data.csv")

# %%
dataset
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset.dropna()
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4404   29        No      Travel_Rarely                   Sales
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %%
dataset.Attrition.replace(to_replace = ('No','Yes'),value = (0,1),inplace = True)

# %%
stats, p = pearsonr(dataset.Attrition, dataset.Age)
print(stats,p)
# Out:
# -0.15920500686577965 1.996801615886744e-26

# %% [markdown]
# # Hypothesis 1
#
# H0 = age & attrition has no correlation
#
# H1 = age & attrition has correlation
#
# r = -0.15920500686577965, i.e there is a negative correalation between age and attrition
#
# p < 0.05, i.e. null hypothesis is rejected.
#
# Hence we can conclude that there is a correalation between age and attrition because null hypothesis is rejected and the correlation between them is negative

# %%
stats, p = pearsonr(dataset.Attrition, dataset.MonthlyIncome)
print(stats,p)
# Out:
# -0.031176281698115007 0.03842748490600132

# %% [markdown]
# # Hypothesis 2
#
# H0 = Monthly Income & attrition has no correlation
#
# H1 = Monthly Income & attrition has correlation
#
# r = -0.031176281698115007, i.e there is a negative correalation between MonthlyIncome and attrition
#
# p < 0.05, i.e. null hypothesis is rejected.
#
# Hence we can conclude that there is a correalation between age and attrition because null hypothesis is rejected and the correlation between them is negative

# %%
stats, p = pearsonr(dataset.Attrition, dataset.YearsWithCurrManager)
print(stats,p)
# Out:
# -0.15619931590162847 1.7339322652896276e-25

# %% [markdown]
# # Hypothesis 3
#
# H0 =YearsWithCurrManager & attrition has no correlation
#
# H1 =YearsWithCurrManager & attrition has correlation
#
# r = -0.15619931590162847, i.e there is a negative correalation between age and attrition
#
# p < 0.05, i.e. null hypothesis is rejected.
#
# Hence we can conclude that there is a correalation between YearsWithCurrManager and attrition because null hypothesis is rejected and the correlation between them is negative

# %%
stats, p = pearsonr(dataset.Attrition, dataset.DistanceFromHome)
print(stats,p)
# Out:
# -0.009730141010179674 0.5182860428050771

# %% [markdown]
# # Hypothesis 3
#
# H0 =DistanceFromHome & attrition has no correlation
#
# H1 =DistanceFromHome & attrition has correlation
#
# r = -0.009730141010179674, i.e there is a negative correalation between age and attrition
#
# p > 0.05, i.e. null hypothesis is accepted & alternate hypothesis is rejected.
#
# Hence we can conclude that there is no correalation between DistanceFromHome and attrition.

# %%
stats, p = pearsonr(dataset.Attrition, dataset.YearsAtCompany)
print(stats,p)
# Out:
# -0.1343922139899772 3.1638831224877484e-19

# %% [markdown]
# # Hypothesis 4
#
# H0 = Monthly Income & attrition has no correlation
#
# H1 = Monthly Income & attrition has correlation
#
# r = -0.1343922139899772, i.e there is a negative correalation between YearsAtCompany and attrition
#
# p < 0.05, i.e. null hypothesis is rejected.
#
# Hence we can conclude that there is a correalation between age and attrition because null hypothesis is rejected and the correlation between them is negative

# %%
stats, p = pearsonr(dataset.Attrition, dataset.Education)
print(stats,p)
# Out:
# -0.015111167710968713 0.3157293177118575

# %% [markdown]
# # Hypothesis 5
#
# H0 =DistanceFromHome & attrition has no correlation
#
# H1 =DistanceFromHome & attrition has correlation
#
# r = -0.015111167710968713, i.e there is a negative correalation between age and attrition
#
# p > 0.05, i.e. null hypothesis is accepted & alternate hypothesis is rejected.
#
# Hence we can conclude that there is no correalation between Education and attrition.

# %%
stats, p = pearsonr(dataset.Attrition, dataset.PercentSalaryHike)
print(stats,p)
# Out:
# 0.03253259489105349 0.030743386433355353

# %% [markdown]
# # Hypothesis 6
#
# H0 =PercentSalaryHike & attrition has no correlation
#
# H1 =PercentSalaryHike & attrition has correlation
#
# r = 0.03253259489105349, i.e there is a positive correalation between PercentSalaryHike and attrition
#
# p < 0.05, i.e. null hypothesis is rejected & alternate hypothesis is accepted
#
# Hence we can conclude that there is positive correalation between PercentSalaryHike and attrition.

# %%
stats, p = pearsonr(dataset.Attrition, dataset.YearsAtCompany)
print(stats,p)
# Out:
# -0.1343922139899772 3.1638831224877484e-19

# %% [markdown]
# # Hypothesis 7
#
# H0 =YearsAtCompany & attrition has no correlation
#
# H1 =YearsAtCompany & attrition has correlation
#
# r = -0.1343922139899772, i.e there is a negative correalation between YearsAtCompany and attrition
#
# p < 0.05, i.e. null hypothesis is rejected & alternate hypothesis is accepted
#
# Hence we can conclude that there is negative correalation between YearsAtCompany and attrition.

# %%
stats, p = pearsonr(dataset.Attrition, dataset.YearsSinceLastPromotion)
print(stats,p)
# Out:
# -0.03301877514258434 0.028330336189396753

# %% [markdown]
# # Hypothesis 8
#
# H0 =YearsSinceLastPromotion & attrition has no correlation
#
# H1 =YearsSinceLastPromotion & attrition has correlation
#
# r = -0.03301877514258434, i.e there is a negative correalation between YearsSinceLastPromotion and attrition
#
# p < 0.05, i.e. null hypothesis is rejected & alternate hypothesis is accepted
#
# Hence we can conclude that there is negative correalation between YearsSinceLastPromotion and attrition.

# %%
stats, p = pearsonr(dataset.Attrition, dataset.TrainingTimesLastYear)
print(stats,p)
# Out:
# -0.049430576244255 0.0010247061915365072

# %% [markdown]
# # Hypothesis 9
#
# H0 =TrainingTimesLastYear& attrition has no correlation
#
# H1 =TrainingTimesLastYear & attrition has correlation
#
# r = -0.049430576244255, i.e there is a negative correalation between TrainingTimesLastYear and attrition
#
# p < 0.05, i.e. null hypothesis is rejected & alternate hypothesis is accepted
#
# Hence we can conclude that there is negative correalation between TrainingTimesLastYear and attrition.
